# %%
import numpy as np
import dedalus.public as d3
import logging
logger = logging.getLogger(__name__)


# Parameters
Lx, Lz = 4, 1
Nx, Nz = 1024, 256
Rayleigh = 2e6
Prandtl = 1
dealias = 3/2
stop_sim_time = 50
timestepper = d3.RK222
max_timestep = 0.125
dtype = np.float64

# Bases
coords = d3.CartesianCoordinates('x', 'z')
dist = d3.Distributor(coords, dtype=dtype)
xbasis = d3.RealFourier(coords['x'], size=Nx, bounds=(0, Lx), dealias=dealias)
zbasis = d3.ChebyshevT(coords['z'], size=Nz, bounds=(0, Lz), dealias=dealias)

# Fields
p = dist.Field(name='p', bases=(xbasis,zbasis))
b = dist.Field(name='b', bases=(xbasis,zbasis))
u = dist.VectorField(coords, name='u', bases=(xbasis,zbasis))
tau_p = dist.Field(name='tau_p')
tau_b1 = dist.Field(name='tau_b1', bases=xbasis)
tau_b2 = dist.Field(name='tau_b2', bases=xbasis)
tau_u1 = dist.VectorField(coords, name='tau_u1', bases=xbasis)
tau_u2 = dist.VectorField(coords, name='tau_u2', bases=xbasis)

# Substitutions
kappa = 2.23e-5
nu = 1.5e-5
x, z = dist.local_grids(xbasis, zbasis)
ex, ez = coords.unit_vector_fields(dist)
lift_basis = zbasis.derivative_basis(1)
lift = lambda A: d3.Lift(A, lift_basis, -1)
grad_u = d3.grad(u) + ez*lift(tau_u1) # First-order reduction
grad_b = d3.grad(b) + ez*lift(tau_b1) # First-order reduction

# Problem
# First-order form: "div(f)" becomes "trace(grad_f)"
# First-order form: "lap(f)" becomes "div(grad_f)"
problem = d3.IVP([p, b, u, tau_p, tau_b1, tau_b2, tau_u1, tau_u2], namespace=locals())
problem.add_equation("trace(grad_u) + tau_p = 0")
problem.add_equation("dt(b) - kappa*div(grad_b) + lift(tau_b2) = - u@grad(b)")
problem.add_equation("dt(u) - nu*div(grad_u) + grad(p) - b*ez + lift(tau_u2) = - u@grad(u)")
problem.add_equation("b(z=0) = Lz")
problem.add_equation("u(z=0) = 0")
problem.add_equation("b(z=Lz) = 0")
problem.add_equation("u(z=Lz) = 0")
problem.add_equation("integ(p) = 0") # Pressure gauge

# Solver
solver = problem.build_solver(timestepper)
solver.stop_sim_time = stop_sim_time

# Initial conditions
b.fill_random('g', seed=42, distribution='normal', scale=1e-3) # Random noise
b['g'] *= z * (Lz - z) # Damp noise at walls
b['g'] += Lz - z # Add linear background

# Analysis
snapshots = solver.evaluator.add_file_handler('snapshots', sim_dt=0.25, max_writes=50)
snapshots.add_task(b, name='buoyancy')
vorticity = -d3.div(d3.skew(u))
snapshots.add_task(vorticity, name='vorticity')

# CFL
CFL = d3.CFL(solver, initial_dt=max_timestep, cadence=5, safety=0.5, threshold=0.05,
             max_change=1.5, min_change=0, max_dt=max_timestep)
CFL.add_velocity(u)

# Flow properties
flow = d3.GlobalFlowProperty(solver, cadence=10)
flow.add_property(np.sqrt(u@u)/nu, name='Re')

# Main loop
startup_iter = 10
try:
    logger.info('Starting main loop')
    while solver.proceed:
        timestep = CFL.compute_timestep()
        solver.step(timestep)
        if (solver.iteration-1) % 10 == 0:
            max_Re = flow.max('Re')
            logger.info('Iteration=%i, Time=%e, dt=%e, max(Re)=%f' %(solver.iteration, solver.sim_time, timestep, max_Re))
except:
    logger.error('Exception raised, triggering end of main loop.')
    raise
finally:
    solver.log_stats()
# Out:
# 2024-04-06 11:54:24,536 subsystems 0/1 INFO :: Building subproblem matrices 1/64 (~2%) Elapsed: 0s, Remaining: 5s, Rate: 1.3e+01/s
# 2024-04-06 11:54:24,739 subsystems 0/1 INFO :: Building subproblem matrices 7/64 (~11%) Elapsed: 0s, Remaining: 2s, Rate: 2.5e+01/s
# 2024-04-06 11:54:24,973 subsystems 0/1 INFO :: Building subproblem matrices 14/64 (~22%) Elapsed: 1s, Remaining: 2s, Rate: 2.7e+01/s
# 2024-04-06 11:54:25,211 subsystems 0/1 INFO :: Building subproblem matrices 21/64 (~33%) Elapsed: 1s, Remaining: 2s, Rate: 2.8e+01/s
# 2024-04-06 11:54:25,444 subsystems 0/1 INFO :: Building subproblem matrices 28/64 (~44%) Elapsed: 1s, Remaining: 1s, Rate: 2.8e+01/s
# 2024-04-06 11:54:25,682 subsystems 0/1 INFO :: Building subproblem matrices 35/64 (~55%) Elapsed: 1s, Remaining: 1s, Rate: 2.9e+01/s
# 2024-04-06 11:54:25,917 subsystems 0/1 INFO :: Building subproblem matrices 42/64 (~66%) Elapsed: 1s, Remaining: 1s, Rate: 2.9e+01/s
# 2024-04-06 11:54:26,149 subsystems 0/1 INFO :: Building subproblem matrices 49/64 (~77%) Elapsed: 2s, Remaining: 1s, Rate: 2.9e+01/s
# 2024-04-06 11:54:26,383 subsystems 0/1 INFO :: Building subproblem matrices 56/64 (~88%) Elapsed: 2s, Remaining: 0s, Rate: 2.9e+01/s
# 2024-04-06 11:54:26,616 subsystems 0/1 INFO :: Building subproblem matrices 63/64 (~98%) Elapsed: 2s, Remaining: 0s, Rate: 2.9e+01/s
# 2024-04-06 11:54:26,651 subsystems 0/1 INFO :: Building subproblem matrices 64/64 (~100%) Elapsed: 2s, Remaining: 0s, Rate: 2.9e+01/s
# 2024-04-06 11:54:26,666 __main__ 0/1 INFO :: Starting main loop
# 2024-04-06 11:54:26,815 __main__ 0/1 INFO :: Iteration=1, Time=1.250000e-01, dt=1.250000e-01, max(Re)=0.000000
# 2024-04-06 11:54:26,984 __main__ 0/1 INFO :: Iteration=11, Time=1.375000e+00, dt=1.250000e-01, max(Re)=35.729940
# 2024-04-06 11:54:27,149 __main__ 0/1 INFO :: Iteration=21, Time=2.625000e+00, dt=1.250000e-01, max(Re)=114.694357
# 2024-04-06 11:54:27,314 __main__ 0/1 INFO :: Iteration=31, Time=3.875000e+00, dt=1.250000e-01, max(Re)=363.092843
# 2024-04-06 11:54:27,473 __main__ 0/1 INFO :: Iteration=41, Time=5.125000e+00, dt=1.250000e-01, max(Re)=1173.672259
# 2024-04-06 11:54:27,635 __main__ 0/1 INFO :: Iteration=51, Time=6.375000e+00, dt=1.250000e-01, max(Re)=3483.783169
# 2024-04-06 11:54:27,795 __main__ 0/1 INFO :: Iteration=61, Time=7.625000e+00, dt=1.250000e-01, max(Re)=10499.288523
# 2024-04-06 11:54:28,069 __main__ 0/1 INFO :: Iteration=71, Time=8.435973e+00, dt=5.931546e-02, max(Re)=20107.175716
# 2024-04-06 11:54:28,323 __main__ 0/1 INFO :: Iteration=81, Time=8.883700e+00, dt=4.339902e-02, max(Re)=23206.949838
# 2024-04-06 11:54:28,593 __main__ 0/1 INFO :: Iteration=91, Time=9.270955e+00, dt=3.681412e-02, max(Re)=31032.403358
# 2024-04-06 11:54:28,844 __main__ 0/1 INFO :: Iteration=101, Time=9.559559e+00, dt=2.620796e-02, max(Re)=34639.757899
# 2024-04-06 11:54:29,042 __main__ 0/1 INFO :: Iteration=111, Time=9.802713e+00, dt=2.431538e-02, max(Re)=32510.525648
# 2024-04-06 11:54:29,289 __main__ 0/1 INFO :: Iteration=121, Time=1.001553e+01, dt=1.997122e-02, max(Re)=32801.153552
# 2024-04-06 11:54:29,543 __main__ 0/1 INFO :: Iteration=131, Time=1.021186e+01, dt=2.036710e-02, max(Re)=36764.611850
# 2024-04-06 11:54:29,745 __main__ 0/1 INFO :: Iteration=141, Time=1.042196e+01, dt=2.165258e-02, max(Re)=35830.580083
# 2024-04-06 11:54:29,927 __main__ 0/1 INFO :: Iteration=151, Time=1.063848e+01, dt=2.165258e-02, max(Re)=41444.327390
# 2024-04-06 11:54:30,146 __main__ 0/1 INFO :: Iteration=161, Time=1.084286e+01, dt=1.922293e-02, max(Re)=42579.644192
# 2024-04-06 11:54:30,362 __main__ 0/1 INFO :: Iteration=171, Time=1.104580e+01, dt=2.029401e-02, max(Re)=50077.590932
# 2024-04-06 11:54:30,560 __main__ 0/1 INFO :: Iteration=181, Time=1.123972e+01, dt=1.848949e-02, max(Re)=48378.627300
# 2024-04-06 11:54:30,763 __main__ 0/1 INFO :: Iteration=191, Time=1.140545e+01, dt=1.657253e-02, max(Re)=47827.105013
# 2024-04-06 11:54:31,019 __main__ 0/1 INFO :: Iteration=201, Time=1.155693e+01, dt=1.514799e-02, max(Re)=50416.123300
# 2024-04-06 11:54:31,221 __main__ 0/1 INFO :: Iteration=211, Time=1.169662e+01, dt=1.278997e-02, max(Re)=47964.958909
# 2024-04-06 11:54:31,480 __main__ 0/1 INFO :: Iteration=221, Time=1.183980e+01, dt=1.474807e-02, max(Re)=46236.732533
# 2024-04-06 11:54:31,623 __main__ 0/1 INFO :: Iteration=231, Time=1.198728e+01, dt=1.474807e-02, max(Re)=52474.799655
# 2024-04-06 11:54:31,827 __main__ 0/1 INFO :: Iteration=241, Time=1.212323e+01, dt=1.359470e-02, max(Re)=51289.452383
# 2024-04-06 11:54:32,080 __main__ 0/1 INFO :: Iteration=251, Time=1.225523e+01, dt=1.373877e-02, max(Re)=57956.314799
# 2024-04-06 11:54:32,334 __main__ 0/1 INFO :: Iteration=261, Time=1.239311e+01, dt=1.306204e-02, max(Re)=55130.885302
# 2024-04-06 11:54:32,550 __main__ 0/1 INFO :: Iteration=271, Time=1.253152e+01, dt=1.384179e-02, max(Re)=59856.306061
# 2024-04-06 11:54:32,751 __main__ 0/1 INFO :: Iteration=281, Time=1.265114e+01, dt=1.196177e-02, max(Re)=55351.490596
# 2024-04-06 11:54:32,900 __main__ 0/1 INFO :: Iteration=291, Time=1.277076e+01, dt=1.196177e-02, max(Re)=55475.301446
# 2024-04-06 11:54:33,043 __main__ 0/1 INFO :: Iteration=301, Time=1.289038e+01, dt=1.196177e-02, max(Re)=61652.986842
# 2024-04-06 11:54:33,247 __main__ 0/1 INFO :: Iteration=311, Time=1.301731e+01, dt=1.269309e-02, max(Re)=62051.471726
# 2024-04-06 11:54:33,531 __main__ 0/1 INFO :: Iteration=321, Time=1.312624e+01, dt=1.023083e-02, max(Re)=66627.070883
# 2024-04-06 11:54:33,731 __main__ 0/1 INFO :: Iteration=331, Time=1.322447e+01, dt=9.416469e-03, max(Re)=63014.664873
# 2024-04-06 11:54:33,999 __main__ 0/1 INFO :: Iteration=341, Time=1.332943e+01, dt=1.084850e-02, max(Re)=62847.906011
# 2024-04-06 11:54:34,151 __main__ 0/1 INFO :: Iteration=351, Time=1.343792e+01, dt=1.084850e-02, max(Re)=65533.230013
# 2024-04-06 11:54:34,408 __main__ 0/1 INFO :: Iteration=361, Time=1.355102e+01, dt=1.078707e-02, max(Re)=61159.951390
# 2024-04-06 11:54:34,553 __main__ 0/1 INFO :: Iteration=371, Time=1.365889e+01, dt=1.078707e-02, max(Re)=65689.339580
# 2024-04-06 11:54:34,760 __main__ 0/1 INFO :: Iteration=381, Time=1.376249e+01, dt=9.933690e-03, max(Re)=67329.115699
# 2024-04-06 11:54:34,958 __main__ 0/1 INFO :: Iteration=391, Time=1.385827e+01, dt=9.221860e-03, max(Re)=68170.463845
# 2024-04-06 11:54:35,155 __main__ 0/1 INFO :: Iteration=401, Time=1.395557e+01, dt=1.023872e-02, max(Re)=68514.429849
# 2024-04-06 11:54:35,302 __main__ 0/1 INFO :: Iteration=411, Time=1.405796e+01, dt=1.023872e-02, max(Re)=72692.610334
# 2024-04-06 11:54:35,501 __main__ 0/1 INFO :: Iteration=421, Time=1.415221e+01, dt=8.610186e-03, max(Re)=66923.130607
# 2024-04-06 11:54:35,694 __main__ 0/1 INFO :: Iteration=431, Time=1.424064e+01, dt=9.076597e-03, max(Re)=70688.298231
# 2024-04-06 11:54:35,973 __main__ 0/1 INFO :: Iteration=441, Time=1.434273e+01, dt=1.048226e-02, max(Re)=72817.993002
# 2024-04-06 11:54:36,115 __main__ 0/1 INFO :: Iteration=451, Time=1.444755e+01, dt=1.048226e-02, max(Re)=75253.943612
# 2024-04-06 11:54:36,363 __main__ 0/1 INFO :: Iteration=461, Time=1.455669e+01, dt=1.023501e-02, max(Re)=75177.687258
# 2024-04-06 11:54:36,568 __main__ 0/1 INFO :: Iteration=471, Time=1.464854e+01, dt=9.185292e-03, max(Re)=77291.326997
# 2024-04-06 11:54:36,762 __main__ 0/1 INFO :: Iteration=481, Time=1.473791e+01, dt=8.689258e-03, max(Re)=75282.392752
# 2024-04-06 11:54:37,008 __main__ 0/1 INFO :: Iteration=491, Time=1.483178e+01, dt=9.636124e-03, max(Re)=76439.669078
# 2024-04-06 11:54:37,201 __main__ 0/1 INFO :: Iteration=501, Time=1.491817e+01, dt=8.638987e-03, max(Re)=78967.764070
# 2024-04-06 11:54:37,389 __main__ 0/1 INFO :: Iteration=511, Time=1.499922e+01, dt=7.571800e-03, max(Re)=76568.608014
# 2024-04-06 11:54:37,583 __main__ 0/1 INFO :: Iteration=521, Time=1.506882e+01, dt=6.959208e-03, max(Re)=81289.636042
# 2024-04-06 11:54:37,823 __main__ 0/1 INFO :: Iteration=531, Time=1.514687e+01, dt=7.306581e-03, max(Re)=72802.168695
# 2024-04-06 11:54:37,959 __main__ 0/1 INFO :: Iteration=541, Time=1.521993e+01, dt=7.306581e-03, max(Re)=91236.443247
# 2024-04-06 11:54:38,145 __main__ 0/1 INFO :: Iteration=551, Time=1.530393e+01, dt=8.399909e-03, max(Re)=77702.063682
# 2024-04-06 11:54:38,280 __main__ 0/1 INFO :: Iteration=561, Time=1.538793e+01, dt=8.399909e-03, max(Re)=69532.869503
# 2024-04-06 11:54:38,521 __main__ 0/1 INFO :: Iteration=571, Time=1.547952e+01, dt=9.450807e-03, max(Re)=75452.265945
# 2024-04-06 11:54:38,658 __main__ 0/1 INFO :: Iteration=581, Time=1.557403e+01, dt=9.450807e-03, max(Re)=75505.647025
# 2024-04-06 11:54:38,842 __main__ 0/1 INFO :: Iteration=591, Time=1.566385e+01, dt=8.513336e-03, max(Re)=85892.596554
# 2024-04-06 11:54:39,080 __main__ 0/1 INFO :: Iteration=601, Time=1.574826e+01, dt=8.840034e-03, max(Re)=74450.749575
# 2024-04-06 11:54:39,221 __main__ 0/1 INFO :: Iteration=611, Time=1.583666e+01, dt=8.840034e-03, max(Re)=79125.925584
# 2024-04-06 11:54:39,459 __main__ 0/1 INFO :: Iteration=621, Time=1.592148e+01, dt=8.736856e-03, max(Re)=80268.332087
# 2024-04-06 11:54:39,603 __main__ 0/1 INFO :: Iteration=631, Time=1.600885e+01, dt=8.736856e-03, max(Re)=73287.912277
# 2024-04-06 11:54:39,745 __main__ 0/1 INFO :: Iteration=641, Time=1.609622e+01, dt=8.736856e-03, max(Re)=66986.880830
# 2024-04-06 11:54:40,001 __main__ 0/1 INFO :: Iteration=651, Time=1.618256e+01, dt=8.071693e-03, max(Re)=76311.118539
# 2024-04-06 11:54:40,239 __main__ 0/1 INFO :: Iteration=661, Time=1.626699e+01, dt=8.104783e-03, max(Re)=79680.819327
# 2024-04-06 11:54:40,490 __main__ 0/1 INFO :: Iteration=671, Time=1.633752e+01, dt=7.284537e-03, max(Re)=77479.185308
# 2024-04-06 11:54:40,686 __main__ 0/1 INFO :: Iteration=681, Time=1.641260e+01, dt=7.731349e-03, max(Re)=75694.867535
# 2024-04-06 11:54:40,927 __main__ 0/1 INFO :: Iteration=691, Time=1.649981e+01, dt=9.037250e-03, max(Re)=71328.625864
# 2024-04-06 11:54:41,115 __main__ 0/1 INFO :: Iteration=701, Time=1.660004e+01, dt=1.002255e-02, max(Re)=69106.697033
# 2024-04-06 11:54:41,362 __main__ 0/1 INFO :: Iteration=711, Time=1.668880e+01, dt=9.189728e-03, max(Re)=98579.478410
# 2024-04-06 11:54:41,598 __main__ 0/1 INFO :: Iteration=721, Time=1.676904e+01, dt=7.811116e-03, max(Re)=96849.309570
# 2024-04-06 11:54:41,732 __main__ 0/1 INFO :: Iteration=731, Time=1.684715e+01, dt=7.811116e-03, max(Re)=83611.781678
# 2024-04-06 11:54:41,863 __main__ 0/1 INFO :: Iteration=741, Time=1.692526e+01, dt=7.811116e-03, max(Re)=82937.270953
# 2024-04-06 11:54:42,005 __main__ 0/1 INFO :: Iteration=751, Time=1.700337e+01, dt=7.811116e-03, max(Re)=83492.724337
# 2024-04-06 11:54:42,265 __main__ 0/1 INFO :: Iteration=761, Time=1.710099e+01, dt=1.043887e-02, max(Re)=69024.777323
# 2024-04-06 11:54:42,494 __main__ 0/1 INFO :: Iteration=771, Time=1.720301e+01, dt=1.054535e-02, max(Re)=64385.036779
# 2024-04-06 11:54:42,751 __main__ 0/1 INFO :: Iteration=781, Time=1.730840e+01, dt=1.126283e-02, max(Re)=61924.544819
# 2024-04-06 11:54:42,982 __main__ 0/1 INFO :: Iteration=791, Time=1.741544e+01, dt=1.014489e-02, max(Re)=70398.917608
# 2024-04-06 11:54:43,176 __main__ 0/1 INFO :: Iteration=801, Time=1.751964e+01, dt=1.069502e-02, max(Re)=66795.098464
# 2024-04-06 11:54:43,366 __main__ 0/1 INFO :: Iteration=811, Time=1.762243e+01, dt=9.863016e-03, max(Re)=68208.100512
# 2024-04-06 11:54:43,509 __main__ 0/1 INFO :: Iteration=821, Time=1.772106e+01, dt=9.863016e-03, max(Re)=69983.456102
# 2024-04-06 11:54:43,712 __main__ 0/1 INFO :: Iteration=831, Time=1.782633e+01, dt=1.119105e-02, max(Re)=65412.688164
# 2024-04-06 11:54:43,855 __main__ 0/1 INFO :: Iteration=841, Time=1.793824e+01, dt=1.119105e-02, max(Re)=69396.307855
# 2024-04-06 11:54:43,997 __main__ 0/1 INFO :: Iteration=851, Time=1.805015e+01, dt=1.119105e-02, max(Re)=68734.327070
# 2024-04-06 11:54:44,191 __main__ 0/1 INFO :: Iteration=861, Time=1.813911e+01, dt=8.895297e-03, max(Re)=80593.151241
# 2024-04-06 11:54:44,383 __main__ 0/1 INFO :: Iteration=871, Time=1.821412e+01, dt=7.501739e-03, max(Re)=93288.005357
# 2024-04-06 11:54:44,587 __main__ 0/1 INFO :: Iteration=881, Time=1.828434e+01, dt=6.540945e-03, max(Re)=89110.252040
# 2024-04-06 11:54:44,781 __main__ 0/1 INFO :: Iteration=891, Time=1.835340e+01, dt=7.271629e-03, max(Re)=82212.242628
# 2024-04-06 11:54:45,021 __main__ 0/1 INFO :: Iteration=901, Time=1.843576e+01, dt=8.595172e-03, max(Re)=69084.138588
# 2024-04-06 11:54:45,278 __main__ 0/1 INFO :: Iteration=911, Time=1.853574e+01, dt=1.059975e-02, max(Re)=62286.603216
# 2024-04-06 11:54:45,521 __main__ 0/1 INFO :: Iteration=921, Time=1.863483e+01, dt=1.023580e-02, max(Re)=66063.075930
# 2024-04-06 11:54:45,713 __main__ 0/1 INFO :: Iteration=931, Time=1.873371e+01, dt=9.540260e-03, max(Re)=67771.146977
# 2024-04-06 11:54:45,914 __main__ 0/1 INFO :: Iteration=941, Time=1.884182e+01, dt=1.081163e-02, max(Re)=72835.892385
# 2024-04-06 11:54:46,161 __main__ 0/1 INFO :: Iteration=951, Time=1.894420e+01, dt=1.053212e-02, max(Re)=66387.971800
# 2024-04-06 11:54:46,356 __main__ 0/1 INFO :: Iteration=961, Time=1.905810e+01, dt=1.139005e-02, max(Re)=71904.306412
# 2024-04-06 11:54:46,554 __main__ 0/1 INFO :: Iteration=971, Time=1.914762e+01, dt=8.952181e-03, max(Re)=81196.781123
# 2024-04-06 11:54:46,797 __main__ 0/1 INFO :: Iteration=981, Time=1.923417e+01, dt=8.974045e-03, max(Re)=69643.325374
# 2024-04-06 11:54:46,999 __main__ 0/1 INFO :: Iteration=991, Time=1.932748e+01, dt=9.686754e-03, max(Re)=65989.564917
# 2024-04-06 11:54:47,143 __main__ 0/1 INFO :: Iteration=1001, Time=1.942435e+01, dt=9.686754e-03, max(Re)=68813.088808
# 2024-04-06 11:54:47,393 __main__ 0/1 INFO :: Iteration=1011, Time=1.952178e+01, dt=9.102380e-03, max(Re)=68785.330139
# 2024-04-06 11:54:47,536 __main__ 0/1 INFO :: Iteration=1021, Time=1.961281e+01, dt=9.102380e-03, max(Re)=74211.787155
# 2024-04-06 11:54:47,732 __main__ 0/1 INFO :: Iteration=1031, Time=1.969197e+01, dt=7.916381e-03, max(Re)=70552.199760
# 2024-04-06 11:54:47,877 __main__ 0/1 INFO :: Iteration=1041, Time=1.977113e+01, dt=7.916381e-03, max(Re)=71583.914475
# 2024-04-06 11:54:48,119 __main__ 0/1 INFO :: Iteration=1051, Time=1.986285e+01, dt=9.737193e-03, max(Re)=65587.503222
# 2024-04-06 11:54:48,314 __main__ 0/1 INFO :: Iteration=1061, Time=1.995722e+01, dt=9.134933e-03, max(Re)=62422.480152
# 2024-04-06 11:54:48,519 __main__ 0/1 INFO :: Iteration=1071, Time=2.005250e+01, dt=9.922761e-03, max(Re)=63402.843776
# 2024-04-06 11:54:48,710 __main__ 0/1 INFO :: Iteration=1081, Time=2.016391e+01, dt=1.114056e-02, max(Re)=75294.749832
# 2024-04-06 11:54:48,912 __main__ 0/1 INFO :: Iteration=1091, Time=2.026072e+01, dt=9.681454e-03, max(Re)=68408.412696
# 2024-04-06 11:54:49,107 __main__ 0/1 INFO :: Iteration=1101, Time=2.036564e+01, dt=1.130164e-02, max(Re)=65756.714573
# 2024-04-06 11:54:49,301 __main__ 0/1 INFO :: Iteration=1111, Time=2.047425e+01, dt=1.041975e-02, max(Re)=66787.806514
# 2024-04-06 11:54:49,448 __main__ 0/1 INFO :: Iteration=1121, Time=2.057844e+01, dt=1.041975e-02, max(Re)=65463.779836
# 2024-04-06 11:54:49,591 __main__ 0/1 INFO :: Iteration=1131, Time=2.068264e+01, dt=1.041975e-02, max(Re)=67748.042529
# 2024-04-06 11:54:49,794 __main__ 0/1 INFO :: Iteration=1141, Time=2.078056e+01, dt=9.792062e-03, max(Re)=61779.661044
# 2024-04-06 11:54:49,988 __main__ 0/1 INFO :: Iteration=1151, Time=2.088267e+01, dt=1.062932e-02, max(Re)=65145.187663
# 2024-04-06 11:54:50,129 __main__ 0/1 INFO :: Iteration=1161, Time=2.098896e+01, dt=1.062932e-02, max(Re)=78994.335994
# 2024-04-06 11:54:50,377 __main__ 0/1 INFO :: Iteration=1171, Time=2.109330e+01, dt=1.086809e-02, max(Re)=68424.473093
# 2024-04-06 11:54:50,514 __main__ 0/1 INFO :: Iteration=1181, Time=2.120198e+01, dt=1.086809e-02, max(Re)=61789.945359
# 2024-04-06 11:54:50,701 __main__ 0/1 INFO :: Iteration=1191, Time=2.131429e+01, dt=1.159288e-02, max(Re)=62184.241201
# 2024-04-06 11:54:50,842 __main__ 0/1 INFO :: Iteration=1201, Time=2.143022e+01, dt=1.159288e-02, max(Re)=66890.964500
# 2024-04-06 11:54:51,109 __main__ 0/1 INFO :: Iteration=1211, Time=2.153613e+01, dt=1.026631e-02, max(Re)=70293.741152
# 2024-04-06 11:54:51,363 __main__ 0/1 INFO :: Iteration=1221, Time=2.163827e+01, dt=1.092010e-02, max(Re)=63206.883640
# 2024-04-06 11:54:51,506 __main__ 0/1 INFO :: Iteration=1231, Time=2.174747e+01, dt=1.092010e-02, max(Re)=63788.602759
# 2024-04-06 11:54:51,746 __main__ 0/1 INFO :: Iteration=1241, Time=2.184600e+01, dt=1.010662e-02, max(Re)=62583.035603
# 2024-04-06 11:54:51,987 __main__ 0/1 INFO :: Iteration=1251, Time=2.195171e+01, dt=1.015327e-02, max(Re)=57386.555003
# 2024-04-06 11:54:52,178 __main__ 0/1 INFO :: Iteration=1261, Time=2.206237e+01, dt=1.197774e-02, max(Re)=60722.910788
# 2024-04-06 11:54:52,418 __main__ 0/1 INFO :: Iteration=1271, Time=2.217142e+01, dt=1.120792e-02, max(Re)=62119.824548
# 2024-04-06 11:54:52,615 __main__ 0/1 INFO :: Iteration=1281, Time=2.228690e+01, dt=1.188803e-02, max(Re)=60090.111558
# 2024-04-06 11:54:52,856 __main__ 0/1 INFO :: Iteration=1291, Time=2.240149e+01, dt=1.189729e-02, max(Re)=64053.855404
# 2024-04-06 11:54:53,097 __main__ 0/1 INFO :: Iteration=1301, Time=2.250239e+01, dt=1.132076e-02, max(Re)=57867.058022
# 2024-04-06 11:54:53,298 __main__ 0/1 INFO :: Iteration=1311, Time=2.261224e+01, dt=1.064895e-02, max(Re)=57694.389279
# 2024-04-06 11:54:53,528 __main__ 0/1 INFO :: Iteration=1321, Time=2.271285e+01, dt=1.048062e-02, max(Re)=61772.223779
# 2024-04-06 11:54:53,722 __main__ 0/1 INFO :: Iteration=1331, Time=2.280091e+01, dt=8.805748e-03, max(Re)=61481.818068
# 2024-04-06 11:54:53,958 __main__ 0/1 INFO :: Iteration=1341, Time=2.290344e+01, dt=1.078012e-02, max(Re)=61281.068476
# 2024-04-06 11:54:54,097 __main__ 0/1 INFO :: Iteration=1351, Time=2.301124e+01, dt=1.078012e-02, max(Re)=60431.032777
# 2024-04-06 11:54:54,239 __main__ 0/1 INFO :: Iteration=1361, Time=2.311904e+01, dt=1.078012e-02, max(Re)=58079.433379
# 2024-04-06 11:54:54,491 __main__ 0/1 INFO :: Iteration=1371, Time=2.322896e+01, dt=1.037036e-02, max(Re)=59746.458456
# 2024-04-06 11:54:54,762 __main__ 0/1 INFO :: Iteration=1381, Time=2.334345e+01, dt=1.178715e-02, max(Re)=61290.407285
# 2024-04-06 11:54:54,904 __main__ 0/1 INFO :: Iteration=1391, Time=2.346132e+01, dt=1.178715e-02, max(Re)=57703.161031
# 2024-04-06 11:54:55,167 __main__ 0/1 INFO :: Iteration=1401, Time=2.356560e+01, dt=1.009019e-02, max(Re)=57566.238725
# 2024-04-06 11:54:55,402 __main__ 0/1 INFO :: Iteration=1411, Time=2.367424e+01, dt=1.033673e-02, max(Re)=53607.230146
# 2024-04-06 11:54:55,653 __main__ 0/1 INFO :: Iteration=1421, Time=2.376842e+01, dt=9.706132e-03, max(Re)=56351.510260
# 2024-04-06 11:54:55,931 __main__ 0/1 INFO :: Iteration=1431, Time=2.387960e+01, dt=9.676364e-03, max(Re)=58124.655592
# 2024-04-06 11:54:56,133 __main__ 0/1 INFO :: Iteration=1441, Time=2.398487e+01, dt=1.137696e-02, max(Re)=56965.265810
# 2024-04-06 11:54:56,334 __main__ 0/1 INFO :: Iteration=1451, Time=2.410218e+01, dt=1.208454e-02, max(Re)=57423.879988
# 2024-04-06 11:54:56,529 __main__ 0/1 INFO :: Iteration=1461, Time=2.421599e+01, dt=1.067860e-02, max(Re)=57912.760292
# 2024-04-06 11:54:56,730 __main__ 0/1 INFO :: Iteration=1471, Time=2.431175e+01, dt=9.575773e-03, max(Re)=61090.198519
# 2024-04-06 11:54:56,925 __main__ 0/1 INFO :: Iteration=1481, Time=2.441945e+01, dt=1.076979e-02, max(Re)=57096.209201
# 2024-04-06 11:54:57,175 __main__ 0/1 INFO :: Iteration=1491, Time=2.451948e+01, dt=1.045889e-02, max(Re)=72755.333338
# 2024-04-06 11:54:57,367 __main__ 0/1 INFO :: Iteration=1501, Time=2.461880e+01, dt=9.405433e-03, max(Re)=64327.306511
# 2024-04-06 11:54:57,506 __main__ 0/1 INFO :: Iteration=1511, Time=2.471286e+01, dt=9.405433e-03, max(Re)=61810.352780
# 2024-04-06 11:54:57,755 __main__ 0/1 INFO :: Iteration=1521, Time=2.480654e+01, dt=9.829429e-03, max(Re)=58619.975899
# 2024-04-06 11:54:57,995 __main__ 0/1 INFO :: Iteration=1531, Time=2.491569e+01, dt=1.120901e-02, max(Re)=53913.206972
# 2024-04-06 11:54:58,198 __main__ 0/1 INFO :: Iteration=1541, Time=2.502339e+01, dt=1.033070e-02, max(Re)=61108.238905
# 2024-04-06 11:54:58,339 __main__ 0/1 INFO :: Iteration=1551, Time=2.512670e+01, dt=1.033070e-02, max(Re)=63311.922309
# 2024-04-06 11:54:58,581 __main__ 0/1 INFO :: Iteration=1561, Time=2.521705e+01, dt=8.357845e-03, max(Re)=77133.030650
# 2024-04-06 11:54:58,770 __main__ 0/1 INFO :: Iteration=1571, Time=2.530620e+01, dt=9.472314e-03, max(Re)=61491.582082
# 2024-04-06 11:54:58,999 __main__ 0/1 INFO :: Iteration=1581, Time=2.541880e+01, dt=1.158487e-02, max(Re)=54764.068261
# 2024-04-06 11:54:59,185 __main__ 0/1 INFO :: Iteration=1591, Time=2.551901e+01, dt=1.002089e-02, max(Re)=58190.100520
# 2024-04-06 11:54:59,380 __main__ 0/1 INFO :: Iteration=1601, Time=2.562426e+01, dt=1.052508e-02, max(Re)=61717.812612
# 2024-04-06 11:54:59,616 __main__ 0/1 INFO :: Iteration=1611, Time=2.572826e+01, dt=1.124960e-02, max(Re)=60211.066386
# 2024-04-06 11:54:59,853 __main__ 0/1 INFO :: Iteration=1621, Time=2.581925e+01, dt=8.861718e-03, max(Re)=56427.035702
# 2024-04-06 11:55:00,051 __main__ 0/1 INFO :: Iteration=1631, Time=2.591528e+01, dt=1.034433e-02, max(Re)=62692.948547
# 2024-04-06 11:55:00,252 __main__ 0/1 INFO :: Iteration=1641, Time=2.601442e+01, dt=9.483408e-03, max(Re)=66470.709110
# 2024-04-06 11:55:00,442 __main__ 0/1 INFO :: Iteration=1651, Time=2.611727e+01, dt=1.028468e-02, max(Re)=66022.352535
# 2024-04-06 11:55:00,635 __main__ 0/1 INFO :: Iteration=1661, Time=2.621521e+01, dt=9.304314e-03, max(Re)=76792.828158
# 2024-04-06 11:55:00,781 __main__ 0/1 INFO :: Iteration=1671, Time=2.630826e+01, dt=9.304314e-03, max(Re)=62159.881177
# 2024-04-06 11:55:01,029 __main__ 0/1 INFO :: Iteration=1681, Time=2.640260e+01, dt=8.891504e-03, max(Re)=60233.832272
# 2024-04-06 11:55:01,277 __main__ 0/1 INFO :: Iteration=1691, Time=2.650461e+01, dt=9.591311e-03, max(Re)=81013.427383
# 2024-04-06 11:55:01,472 __main__ 0/1 INFO :: Iteration=1701, Time=2.659687e+01, dt=8.861817e-03, max(Re)=64067.999155
# 2024-04-06 11:55:01,708 __main__ 0/1 INFO :: Iteration=1711, Time=2.667966e+01, dt=8.898168e-03, max(Re)=60882.133976
# 2024-04-06 11:55:01,899 __main__ 0/1 INFO :: Iteration=1721, Time=2.677407e+01, dt=9.983148e-03, max(Re)=53850.408432
# 2024-04-06 11:55:02,085 __main__ 0/1 INFO :: Iteration=1731, Time=2.688620e+01, dt=1.121377e-02, max(Re)=69924.831978
# 2024-04-06 11:55:02,329 __main__ 0/1 INFO :: Iteration=1741, Time=2.698840e+01, dt=1.060592e-02, max(Re)=54201.616752
# 2024-04-06 11:55:02,531 __main__ 0/1 INFO :: Iteration=1751, Time=2.710413e+01, dt=1.157307e-02, max(Re)=61575.835685
# 2024-04-06 11:55:02,721 __main__ 0/1 INFO :: Iteration=1761, Time=2.720171e+01, dt=9.758236e-03, max(Re)=62490.125430
# 2024-04-06 11:55:02,918 __main__ 0/1 INFO :: Iteration=1771, Time=2.730270e+01, dt=1.043935e-02, max(Re)=60571.180824
# 2024-04-06 11:55:03,114 __main__ 0/1 INFO :: Iteration=1781, Time=2.741612e+01, dt=1.134174e-02, max(Re)=57066.784593
# 2024-04-06 11:55:03,316 __main__ 0/1 INFO :: Iteration=1791, Time=2.752403e+01, dt=1.023999e-02, max(Re)=57586.473308
# 2024-04-06 11:55:03,513 __main__ 0/1 INFO :: Iteration=1801, Time=2.761977e+01, dt=9.573999e-03, max(Re)=88840.179892
# 2024-04-06 11:55:03,710 __main__ 0/1 INFO :: Iteration=1811, Time=2.770175e+01, dt=8.198069e-03, max(Re)=59307.943536
# 2024-04-06 11:55:03,955 __main__ 0/1 INFO :: Iteration=1821, Time=2.781246e+01, dt=1.183027e-02, max(Re)=63678.398839
# 2024-04-06 11:55:04,146 __main__ 0/1 INFO :: Iteration=1831, Time=2.791463e+01, dt=1.021656e-02, max(Re)=63604.322480
# 2024-04-06 11:55:04,393 __main__ 0/1 INFO :: Iteration=1841, Time=2.799850e+01, dt=7.712929e-03, max(Re)=95230.888431
# 2024-04-06 11:55:04,585 __main__ 0/1 INFO :: Iteration=1851, Time=2.808053e+01, dt=8.693520e-03, max(Re)=61302.407459
# 2024-04-06 11:55:04,833 __main__ 0/1 INFO :: Iteration=1861, Time=2.818577e+01, dt=1.105419e-02, max(Re)=52157.118888
# 2024-04-06 11:55:05,097 __main__ 0/1 INFO :: Iteration=1871, Time=2.828295e+01, dt=1.016302e-02, max(Re)=53667.464949
# 2024-04-06 11:55:05,288 __main__ 0/1 INFO :: Iteration=1881, Time=2.838713e+01, dt=1.067312e-02, max(Re)=55149.441574
# 2024-04-06 11:55:05,476 __main__ 0/1 INFO :: Iteration=1891, Time=2.849983e+01, dt=1.186742e-02, max(Re)=63586.690552
# 2024-04-06 11:55:05,729 __main__ 0/1 INFO :: Iteration=1901, Time=2.858027e+01, dt=7.447642e-03, max(Re)=58829.751113
# 2024-04-06 11:55:05,967 __main__ 0/1 INFO :: Iteration=1911, Time=2.867915e+01, dt=1.079908e-02, max(Re)=65506.734651
# 2024-04-06 11:55:06,160 __main__ 0/1 INFO :: Iteration=1921, Time=2.876003e+01, dt=8.087842e-03, max(Re)=88066.369228
# 2024-04-06 11:55:06,352 __main__ 0/1 INFO :: Iteration=1931, Time=2.884633e+01, dt=8.629627e-03, max(Re)=63293.844586
# 2024-04-06 11:55:06,597 __main__ 0/1 INFO :: Iteration=1941, Time=2.895082e+01, dt=1.012586e-02, max(Re)=60619.688365
# 2024-04-06 11:55:06,795 __main__ 0/1 INFO :: Iteration=1951, Time=2.905483e+01, dt=1.067562e-02, max(Re)=61888.079909
# 2024-04-06 11:55:07,053 __main__ 0/1 INFO :: Iteration=1961, Time=2.914566e+01, dt=9.783423e-03, max(Re)=61266.164523
# 2024-04-06 11:55:07,300 __main__ 0/1 INFO :: Iteration=1971, Time=2.922707e+01, dt=7.772615e-03, max(Re)=60949.517080
# 2024-04-06 11:55:07,556 __main__ 0/1 INFO :: Iteration=1981, Time=2.931877e+01, dt=9.623204e-03, max(Re)=61865.238911
# 2024-04-06 11:55:07,699 __main__ 0/1 INFO :: Iteration=1991, Time=2.941500e+01, dt=9.623204e-03, max(Re)=63439.390954
# 2024-04-06 11:55:07,895 __main__ 0/1 INFO :: Iteration=2001, Time=2.950473e+01, dt=8.973319e-03, max(Re)=60461.913159
# 2024-04-06 11:55:08,089 __main__ 0/1 INFO :: Iteration=2011, Time=2.960626e+01, dt=1.133211e-02, max(Re)=57484.441197
# 2024-04-06 11:55:08,281 __main__ 0/1 INFO :: Iteration=2021, Time=2.971335e+01, dt=1.070923e-02, max(Re)=61861.895629
# 2024-04-06 11:55:08,479 __main__ 0/1 INFO :: Iteration=2031, Time=2.980518e+01, dt=9.182384e-03, max(Re)=64435.838849
# 2024-04-06 11:55:08,720 __main__ 0/1 INFO :: Iteration=2041, Time=2.989759e+01, dt=1.021248e-02, max(Re)=58884.165527
# 2024-04-06 11:55:08,981 __main__ 0/1 INFO :: Iteration=2051, Time=3.000062e+01, dt=9.689532e-03, max(Re)=57064.537825
# 2024-04-06 11:55:09,181 __main__ 0/1 INFO :: Iteration=2061, Time=3.008630e+01, dt=8.568351e-03, max(Re)=63961.930491
# 2024-04-06 11:55:09,423 __main__ 0/1 INFO :: Iteration=2071, Time=3.016822e+01, dt=8.786396e-03, max(Re)=58837.943734
# 2024-04-06 11:55:09,569 __main__ 0/1 INFO :: Iteration=2081, Time=3.025609e+01, dt=8.786396e-03, max(Re)=63055.199652
# 2024-04-06 11:55:09,768 __main__ 0/1 INFO :: Iteration=2091, Time=3.036636e+01, dt=1.102766e-02, max(Re)=56737.078500
# 2024-04-06 11:55:10,012 __main__ 0/1 INFO :: Iteration=2101, Time=3.047772e+01, dt=1.050411e-02, max(Re)=61928.497786
# 2024-04-06 11:55:10,254 __main__ 0/1 INFO :: Iteration=2111, Time=3.055933e+01, dt=7.809243e-03, max(Re)=60551.408157
# 2024-04-06 11:55:10,396 __main__ 0/1 INFO :: Iteration=2121, Time=3.063742e+01, dt=7.809243e-03, max(Re)=63196.168102
# 2024-04-06 11:55:10,643 __main__ 0/1 INFO :: Iteration=2131, Time=3.073334e+01, dt=1.084898e-02, max(Re)=52725.999473
# 2024-04-06 11:55:10,911 __main__ 0/1 INFO :: Iteration=2141, Time=3.083876e+01, dt=1.114459e-02, max(Re)=59742.829442
# 2024-04-06 11:55:11,104 __main__ 0/1 INFO :: Iteration=2151, Time=3.094398e+01, dt=1.052229e-02, max(Re)=62902.532981
# 2024-04-06 11:55:11,360 __main__ 0/1 INFO :: Iteration=2161, Time=3.104696e+01, dt=1.070051e-02, max(Re)=60247.719869
# 2024-04-06 11:55:11,501 __main__ 0/1 INFO :: Iteration=2171, Time=3.115396e+01, dt=1.070051e-02, max(Re)=65725.917456
# 2024-04-06 11:55:11,744 __main__ 0/1 INFO :: Iteration=2181, Time=3.125345e+01, dt=1.076058e-02, max(Re)=59754.043729
# 2024-04-06 11:55:11,946 __main__ 0/1 INFO :: Iteration=2191, Time=3.135424e+01, dt=1.007905e-02, max(Re)=60713.294284
# 2024-04-06 11:55:12,089 __main__ 0/1 INFO :: Iteration=2201, Time=3.145503e+01, dt=1.007905e-02, max(Re)=74090.238228
# 2024-04-06 11:55:12,369 __main__ 0/1 INFO :: Iteration=2211, Time=3.155084e+01, dt=1.002470e-02, max(Re)=55079.864357
# 2024-04-06 11:55:12,577 __main__ 0/1 INFO :: Iteration=2221, Time=3.166303e+01, dt=1.121892e-02, max(Re)=62878.342818
# 2024-04-06 11:55:12,774 __main__ 0/1 INFO :: Iteration=2231, Time=3.176225e+01, dt=9.922024e-03, max(Re)=63780.537762
# 2024-04-06 11:55:12,966 __main__ 0/1 INFO :: Iteration=2241, Time=3.185538e+01, dt=9.313415e-03, max(Re)=59149.209972
# 2024-04-06 11:55:13,105 __main__ 0/1 INFO :: Iteration=2251, Time=3.194851e+01, dt=9.313415e-03, max(Re)=58214.405642
# 2024-04-06 11:55:13,300 __main__ 0/1 INFO :: Iteration=2261, Time=3.204692e+01, dt=9.840317e-03, max(Re)=60822.186549
# 2024-04-06 11:55:13,549 __main__ 0/1 INFO :: Iteration=2271, Time=3.212271e+01, dt=6.960752e-03, max(Re)=62296.114303
# 2024-04-06 11:55:13,787 __main__ 0/1 INFO :: Iteration=2281, Time=3.220586e+01, dt=8.861891e-03, max(Re)=55902.216205
# 2024-04-06 11:55:14,028 __main__ 0/1 INFO :: Iteration=2291, Time=3.230439e+01, dt=1.038411e-02, max(Re)=61774.348132
# 2024-04-06 11:55:14,211 __main__ 0/1 INFO :: Iteration=2301, Time=3.241432e+01, dt=1.160156e-02, max(Re)=59626.009452
# 2024-04-06 11:55:14,458 __main__ 0/1 INFO :: Iteration=2311, Time=3.252247e+01, dt=1.109855e-02, max(Re)=64082.966243
# 2024-04-06 11:55:14,706 __main__ 0/1 INFO :: Iteration=2321, Time=3.262147e+01, dt=1.024389e-02, max(Re)=59444.458373
# 2024-04-06 11:55:14,966 __main__ 0/1 INFO :: Iteration=2331, Time=3.270771e+01, dt=7.926367e-03, max(Re)=66465.450358
# 2024-04-06 11:55:15,228 __main__ 0/1 INFO :: Iteration=2341, Time=3.278741e+01, dt=7.358373e-03, max(Re)=70054.432714
# 2024-04-06 11:55:15,474 __main__ 0/1 INFO :: Iteration=2351, Time=3.287390e+01, dt=9.328976e-03, max(Re)=72782.359943
# 2024-04-06 11:55:15,672 __main__ 0/1 INFO :: Iteration=2361, Time=3.295469e+01, dt=8.079066e-03, max(Re)=67179.240400
# 2024-04-06 11:55:15,928 __main__ 0/1 INFO :: Iteration=2371, Time=3.305133e+01, dt=1.021542e-02, max(Re)=58564.418931
# 2024-04-06 11:55:16,177 __main__ 0/1 INFO :: Iteration=2381, Time=3.314045e+01, dt=8.643929e-03, max(Re)=63684.088367
# 2024-04-06 11:55:16,364 __main__ 0/1 INFO :: Iteration=2391, Time=3.323045e+01, dt=9.356885e-03, max(Re)=69339.694453
# 2024-04-06 11:55:16,616 __main__ 0/1 INFO :: Iteration=2401, Time=3.332242e+01, dt=8.496248e-03, max(Re)=73205.852028
# 2024-04-06 11:55:16,813 __main__ 0/1 INFO :: Iteration=2411, Time=3.341190e+01, dt=8.947454e-03, max(Re)=69633.224241
# 2024-04-06 11:55:17,060 __main__ 0/1 INFO :: Iteration=2421, Time=3.349411e+01, dt=7.946962e-03, max(Re)=72745.736215
# 2024-04-06 11:55:17,208 __main__ 0/1 INFO :: Iteration=2431, Time=3.357358e+01, dt=7.946962e-03, max(Re)=73294.209804
# 2024-04-06 11:55:17,397 __main__ 0/1 INFO :: Iteration=2441, Time=3.365522e+01, dt=8.381554e-03, max(Re)=61791.973104
# 2024-04-06 11:55:17,540 __main__ 0/1 INFO :: Iteration=2451, Time=3.373903e+01, dt=8.381554e-03, max(Re)=60386.739086
# 2024-04-06 11:55:17,735 __main__ 0/1 INFO :: Iteration=2461, Time=3.384087e+01, dt=1.018397e-02, max(Re)=61624.351818
# 2024-04-06 11:55:17,980 __main__ 0/1 INFO :: Iteration=2471, Time=3.393182e+01, dt=8.742175e-03, max(Re)=59809.936062
# 2024-04-06 11:55:18,170 __main__ 0/1 INFO :: Iteration=2481, Time=3.402310e+01, dt=9.514842e-03, max(Re)=68605.875883
# 2024-04-06 11:55:18,361 __main__ 0/1 INFO :: Iteration=2491, Time=3.412147e+01, dt=1.015801e-02, max(Re)=59963.781657
# 2024-04-06 11:55:18,559 __main__ 0/1 INFO :: Iteration=2501, Time=3.420968e+01, dt=8.821540e-03, max(Re)=77826.741242
# 2024-04-06 11:55:18,809 __main__ 0/1 INFO :: Iteration=2511, Time=3.429848e+01, dt=8.220066e-03, max(Re)=71591.090140
# 2024-04-06 11:55:19,045 __main__ 0/1 INFO :: Iteration=2521, Time=3.437269e+01, dt=7.803626e-03, max(Re)=78221.661209
# 2024-04-06 11:55:19,287 __main__ 0/1 INFO :: Iteration=2531, Time=3.446313e+01, dt=9.556705e-03, max(Re)=65463.003328
# 2024-04-06 11:55:19,483 __main__ 0/1 INFO :: Iteration=2541, Time=3.455372e+01, dt=9.059487e-03, max(Re)=77292.271611
# 2024-04-06 11:55:19,719 __main__ 0/1 INFO :: Iteration=2551, Time=3.462917e+01, dt=7.213462e-03, max(Re)=81180.429961
# 2024-04-06 11:55:19,907 __main__ 0/1 INFO :: Iteration=2561, Time=3.470834e+01, dt=7.917760e-03, max(Re)=70856.700443
# 2024-04-06 11:55:20,107 __main__ 0/1 INFO :: Iteration=2571, Time=3.479305e+01, dt=8.470800e-03, max(Re)=71283.542767
# 2024-04-06 11:55:20,345 __main__ 0/1 INFO :: Iteration=2581, Time=3.486976e+01, dt=7.863145e-03, max(Re)=75381.165888
# 2024-04-06 11:55:20,763 __main__ 0/1 INFO :: Iteration=2591, Time=3.496434e+01, dt=9.793213e-03, max(Re)=69649.034292
# 2024-04-06 11:55:21,022 __main__ 0/1 INFO :: Iteration=2601, Time=3.504709e+01, dt=7.967278e-03, max(Re)=75688.716996
# 2024-04-06 11:55:21,219 __main__ 0/1 INFO :: Iteration=2611, Time=3.513464e+01, dt=8.755292e-03, max(Re)=80200.614087
# 2024-04-06 11:55:21,468 __main__ 0/1 INFO :: Iteration=2621, Time=3.521197e+01, dt=7.147645e-03, max(Re)=68471.388439
# 2024-04-06 11:55:21,661 __main__ 0/1 INFO :: Iteration=2631, Time=3.529655e+01, dt=8.458555e-03, max(Re)=71477.450901
# 2024-04-06 11:55:21,858 __main__ 0/1 INFO :: Iteration=2641, Time=3.537278e+01, dt=7.622338e-03, max(Re)=92084.327090
# 2024-04-06 11:55:22,057 __main__ 0/1 INFO :: Iteration=2651, Time=3.544192e+01, dt=6.914517e-03, max(Re)=97828.488146
# 2024-04-06 11:55:22,203 __main__ 0/1 INFO :: Iteration=2661, Time=3.551107e+01, dt=6.914517e-03, max(Re)=85254.187555
# 2024-04-06 11:55:22,447 __main__ 0/1 INFO :: Iteration=2671, Time=3.557895e+01, dt=7.312050e-03, max(Re)=81647.502440
# 2024-04-06 11:55:22,731 __main__ 0/1 INFO :: Iteration=2681, Time=3.564996e+01, dt=6.476534e-03, max(Re)=97008.398094
# 2024-04-06 11:55:22,980 __main__ 0/1 INFO :: Iteration=2691, Time=3.571640e+01, dt=7.182413e-03, max(Re)=110837.322245
# 2024-04-06 11:55:23,183 __main__ 0/1 INFO :: Iteration=2701, Time=3.578126e+01, dt=6.486049e-03, max(Re)=105664.086535
# 2024-04-06 11:55:23,376 __main__ 0/1 INFO :: Iteration=2711, Time=3.585136e+01, dt=7.010109e-03, max(Re)=90084.635529
# 2024-04-06 11:55:23,617 __main__ 0/1 INFO :: Iteration=2721, Time=3.590769e+01, dt=5.324813e-03, max(Re)=88540.547753
# 2024-04-06 11:55:23,810 __main__ 0/1 INFO :: Iteration=2731, Time=3.597060e+01, dt=6.291174e-03, max(Re)=93716.739140
# 2024-04-06 11:55:24,055 __main__ 0/1 INFO :: Iteration=2741, Time=3.602745e+01, dt=5.941982e-03, max(Re)=98336.816666
# 2024-04-06 11:55:24,308 __main__ 0/1 INFO :: Iteration=2751, Time=3.609634e+01, dt=7.082975e-03, max(Re)=102573.991618
# 2024-04-06 11:55:24,555 __main__ 0/1 INFO :: Iteration=2761, Time=3.615925e+01, dt=5.950909e-03, max(Re)=102831.852710
# 2024-04-06 11:55:24,801 __main__ 0/1 INFO :: Iteration=2771, Time=3.622028e+01, dt=5.757301e-03, max(Re)=99641.587617
# 2024-04-06 11:55:24,989 __main__ 0/1 INFO :: Iteration=2781, Time=3.628060e+01, dt=6.305483e-03, max(Re)=83178.317474
# 2024-04-06 11:55:25,128 __main__ 0/1 INFO :: Iteration=2791, Time=3.634365e+01, dt=6.305483e-03, max(Re)=121016.440049
# 2024-04-06 11:55:25,324 __main__ 0/1 INFO :: Iteration=2801, Time=3.640427e+01, dt=5.818704e-03, max(Re)=103603.599689
# 2024-04-06 11:55:25,590 __main__ 0/1 INFO :: Iteration=2811, Time=3.645250e+01, dt=5.045387e-03, max(Re)=97025.813411
# 2024-04-06 11:55:25,788 __main__ 0/1 INFO :: Iteration=2821, Time=3.651033e+01, dt=5.783497e-03, max(Re)=114078.280750
# 2024-04-06 11:55:26,027 __main__ 0/1 INFO :: Iteration=2831, Time=3.656501e+01, dt=5.646878e-03, max(Re)=112282.673062
# 2024-04-06 11:55:26,274 __main__ 0/1 INFO :: Iteration=2841, Time=3.662077e+01, dt=4.953918e-03, max(Re)=98885.197446
# 2024-04-06 11:55:26,517 __main__ 0/1 INFO :: Iteration=2851, Time=3.667495e+01, dt=5.146525e-03, max(Re)=116156.365599
# 2024-04-06 11:55:26,769 __main__ 0/1 INFO :: Iteration=2861, Time=3.672598e+01, dt=5.469114e-03, max(Re)=105273.945364
# 2024-04-06 11:55:27,022 __main__ 0/1 INFO :: Iteration=2871, Time=3.677301e+01, dt=4.428609e-03, max(Re)=129739.971319
# 2024-04-06 11:55:27,208 __main__ 0/1 INFO :: Iteration=2881, Time=3.682572e+01, dt=5.271093e-03, max(Re)=130332.603726
# 2024-04-06 11:55:27,447 __main__ 0/1 INFO :: Iteration=2891, Time=3.687268e+01, dt=4.432089e-03, max(Re)=122568.260818
# 2024-04-06 11:55:27,695 __main__ 0/1 INFO :: Iteration=2901, Time=3.692296e+01, dt=5.270818e-03, max(Re)=127978.439330
# 2024-04-06 11:55:27,929 __main__ 0/1 INFO :: Iteration=2911, Time=3.697046e+01, dt=4.585026e-03, max(Re)=135586.864608
# 2024-04-06 11:55:28,126 __main__ 0/1 INFO :: Iteration=2921, Time=3.701491e+01, dt=4.304836e-03, max(Re)=153661.616836
# 2024-04-06 11:55:28,374 __main__ 0/1 INFO :: Iteration=2931, Time=3.705078e+01, dt=3.323765e-03, max(Re)=201446.288104
# 2024-04-06 11:55:28,619 __main__ 0/1 INFO :: Iteration=2941, Time=3.708510e+01, dt=3.279845e-03, max(Re)=185672.985680
# 2024-04-06 11:55:28,858 __main__ 0/1 INFO :: Iteration=2951, Time=3.712055e+01, dt=3.359667e-03, max(Re)=165027.675664
# 2024-04-06 11:55:29,052 __main__ 0/1 INFO :: Iteration=2961, Time=3.715281e+01, dt=3.091756e-03, max(Re)=156193.029928
# 2024-04-06 11:55:29,300 __main__ 0/1 INFO :: Iteration=2971, Time=3.718939e+01, dt=3.945851e-03, max(Re)=144110.539797
# 2024-04-06 11:55:29,552 __main__ 0/1 INFO :: Iteration=2981, Time=3.722725e+01, dt=3.225057e-03, max(Re)=181193.614389
# 2024-04-06 11:55:29,750 __main__ 0/1 INFO :: Iteration=2991, Time=3.726322e+01, dt=3.597177e-03, max(Re)=178561.648002
# 2024-04-06 11:55:29,994 __main__ 0/1 INFO :: Iteration=3001, Time=3.729636e+01, dt=3.699943e-03, max(Re)=205114.041522
# 2024-04-06 11:55:30,137 __main__ 0/1 INFO :: Iteration=3011, Time=3.733336e+01, dt=3.699943e-03, max(Re)=164048.535376
# 2024-04-06 11:55:30,331 __main__ 0/1 INFO :: Iteration=3021, Time=3.737202e+01, dt=4.031948e-03, max(Re)=156795.043210
# 2024-04-06 11:55:30,471 __main__ 0/1 INFO :: Iteration=3031, Time=3.741234e+01, dt=4.031948e-03, max(Re)=162109.412582
# 2024-04-06 11:55:30,718 __main__ 0/1 INFO :: Iteration=3041, Time=3.745292e+01, dt=4.462631e-03, max(Re)=169135.920111
# 2024-04-06 11:55:30,917 __main__ 0/1 INFO :: Iteration=3051, Time=3.748874e+01, dt=3.581859e-03, max(Re)=156311.422199
# 2024-04-06 11:55:31,123 __main__ 0/1 INFO :: Iteration=3061, Time=3.752639e+01, dt=3.949273e-03, max(Re)=155066.965432
# 2024-04-06 11:55:31,317 __main__ 0/1 INFO :: Iteration=3071, Time=3.756449e+01, dt=3.670633e-03, max(Re)=161578.650439
# 2024-04-06 11:55:31,455 __main__ 0/1 INFO :: Iteration=3081, Time=3.760120e+01, dt=3.670633e-03, max(Re)=150786.259729
# 2024-04-06 11:55:31,594 __main__ 0/1 INFO :: Iteration=3091, Time=3.763790e+01, dt=3.670633e-03, max(Re)=171037.390181
# 2024-04-06 11:55:31,790 __main__ 0/1 INFO :: Iteration=3101, Time=3.767772e+01, dt=4.293558e-03, max(Re)=176120.683595
# 2024-04-06 11:55:32,034 __main__ 0/1 INFO :: Iteration=3111, Time=3.771486e+01, dt=3.998292e-03, max(Re)=172837.001343
# 2024-04-06 11:55:32,263 __main__ 0/1 INFO :: Iteration=3121, Time=3.774801e+01, dt=3.314359e-03, max(Re)=193360.107623
# 2024-04-06 11:55:32,519 __main__ 0/1 INFO :: Iteration=3131, Time=3.778109e+01, dt=3.472739e-03, max(Re)=149517.635395
# 2024-04-06 11:55:32,719 __main__ 0/1 INFO :: Iteration=3141, Time=3.781159e+01, dt=3.050347e-03, max(Re)=173038.585562
# 2024-04-06 11:55:32,911 __main__ 0/1 INFO :: Iteration=3151, Time=3.784599e+01, dt=3.439284e-03, max(Re)=165384.375180
# 2024-04-06 11:55:33,105 __main__ 0/1 INFO :: Iteration=3161, Time=3.787844e+01, dt=3.051912e-03, max(Re)=168459.062466
# 2024-04-06 11:55:33,356 __main__ 0/1 INFO :: Iteration=3171, Time=3.791162e+01, dt=2.994583e-03, max(Re)=213814.411964
# 2024-04-06 11:55:33,555 __main__ 0/1 INFO :: Iteration=3181, Time=3.794335e+01, dt=3.173808e-03, max(Re)=199889.475695
# 2024-04-06 11:55:33,741 __main__ 0/1 INFO :: Iteration=3191, Time=3.797384e+01, dt=2.924300e-03, max(Re)=221381.907668
# 2024-04-06 11:55:33,934 __main__ 0/1 INFO :: Iteration=3201, Time=3.800012e+01, dt=2.331140e-03, max(Re)=205494.431370
# 2024-04-06 11:55:34,132 __main__ 0/1 INFO :: Iteration=3211, Time=3.802569e+01, dt=2.782071e-03, max(Re)=187487.237020
# 2024-04-06 11:55:34,383 __main__ 0/1 INFO :: Iteration=3221, Time=3.805702e+01, dt=2.983774e-03, max(Re)=210974.754702
# 2024-04-06 11:55:34,718 __main__ 0/1 INFO :: Iteration=3231, Time=3.808467e+01, dt=2.548220e-03, max(Re)=199656.943034
# 2024-04-06 11:55:34,913 __main__ 0/1 INFO :: Iteration=3241, Time=3.811285e+01, dt=2.817844e-03, max(Re)=231215.573879
# 2024-04-06 11:55:35,162 __main__ 0/1 INFO :: Iteration=3251, Time=3.813810e+01, dt=2.683219e-03, max(Re)=259111.404635
# 2024-04-06 11:55:35,305 __main__ 0/1 INFO :: Iteration=3261, Time=3.816493e+01, dt=2.683219e-03, max(Re)=239249.666757
# 2024-04-06 11:55:35,445 __main__ 0/1 INFO :: Iteration=3271, Time=3.819176e+01, dt=2.683219e-03, max(Re)=216797.797331
# 2024-04-06 11:55:35,586 __main__ 0/1 INFO :: Iteration=3281, Time=3.821859e+01, dt=2.683219e-03, max(Re)=197620.792864
# 2024-04-06 11:55:35,783 __main__ 0/1 INFO :: Iteration=3291, Time=3.824618e+01, dt=2.833476e-03, max(Re)=208720.930872
# 2024-04-06 11:55:36,000 __main__ 0/1 INFO :: Iteration=3301, Time=3.827305e+01, dt=2.542156e-03, max(Re)=223908.800888
# 2024-04-06 11:55:36,251 __main__ 0/1 INFO :: Iteration=3311, Time=3.829811e+01, dt=2.332267e-03, max(Re)=297442.612113
# 2024-04-06 11:55:36,439 __main__ 0/1 INFO :: Iteration=3321, Time=3.832291e+01, dt=2.480000e-03, max(Re)=249138.490200
# 2024-04-06 11:55:36,582 __main__ 0/1 INFO :: Iteration=3331, Time=3.834771e+01, dt=2.480000e-03, max(Re)=228521.698572
# 2024-04-06 11:55:36,775 __main__ 0/1 INFO :: Iteration=3341, Time=3.836941e+01, dt=2.169976e-03, max(Re)=230423.769454
# 2024-04-06 11:55:36,955 __main__ 0/1 INFO :: Iteration=3351, Time=3.839231e+01, dt=2.289910e-03, max(Re)=283711.091357
# 2024-04-06 11:55:37,146 __main__ 0/1 INFO :: Iteration=3361, Time=3.841440e+01, dt=2.128517e-03, max(Re)=281827.028159
# 2024-04-06 11:55:37,395 __main__ 0/1 INFO :: Iteration=3371, Time=3.843257e+01, dt=1.868050e-03, max(Re)=279046.730888
# 2024-04-06 11:55:37,590 __main__ 0/1 INFO :: Iteration=3381, Time=3.845358e+01, dt=2.333210e-03, max(Re)=295880.225312
# 2024-04-06 11:55:37,838 __main__ 0/1 INFO :: Iteration=3391, Time=3.847436e+01, dt=1.974050e-03, max(Re)=315390.199426
# 2024-04-06 11:55:37,976 __main__ 0/1 INFO :: Iteration=3401, Time=3.849410e+01, dt=1.974050e-03, max(Re)=377404.943345
# 2024-04-06 11:55:38,118 __main__ 0/1 INFO :: Iteration=3411, Time=3.851384e+01, dt=1.974050e-03, max(Re)=312966.620415
# 2024-04-06 11:55:38,371 __main__ 0/1 INFO :: Iteration=3421, Time=3.853109e+01, dt=1.584194e-03, max(Re)=359044.826566
# 2024-04-06 11:55:38,570 __main__ 0/1 INFO :: Iteration=3431, Time=3.854865e+01, dt=1.928341e-03, max(Re)=284248.490982
# 2024-04-06 11:55:38,851 __main__ 0/1 INFO :: Iteration=3441, Time=3.856737e+01, dt=1.700882e-03, max(Re)=336888.834072
# 2024-04-06 11:55:39,105 __main__ 0/1 INFO :: Iteration=3451, Time=3.858624e+01, dt=1.974276e-03, max(Re)=292896.982335
# 2024-04-06 11:55:39,305 __main__ 0/1 INFO :: Iteration=3461, Time=3.860512e+01, dt=1.800884e-03, max(Re)=337470.360724
# 2024-04-06 11:55:39,499 __main__ 0/1 INFO :: Iteration=3471, Time=3.862415e+01, dt=2.006098e-03, max(Re)=305469.094386
# 2024-04-06 11:55:39,697 __main__ 0/1 INFO :: Iteration=3481, Time=3.864333e+01, dt=1.829077e-03, max(Re)=321076.306569
# 2024-04-06 11:55:39,944 __main__ 0/1 INFO :: Iteration=3491, Time=3.866022e+01, dt=1.745570e-03, max(Re)=337628.481752
# 2024-04-06 11:55:40,188 __main__ 0/1 INFO :: Iteration=3501, Time=3.867615e+01, dt=1.647861e-03, max(Re)=341994.163586
# 2024-04-06 11:55:40,379 __main__ 0/1 INFO :: Iteration=3511, Time=3.869375e+01, dt=1.872428e-03, max(Re)=322524.448768
# 2024-04-06 11:55:40,570 __main__ 0/1 INFO :: Iteration=3521, Time=3.871138e+01, dt=1.653914e-03, max(Re)=377095.213795
# 2024-04-06 11:55:40,802 __main__ 0/1 INFO :: Iteration=3531, Time=3.872571e+01, dt=1.366951e-03, max(Re)=407856.698113
# 2024-04-06 11:55:40,939 __main__ 0/1 INFO :: Iteration=3541, Time=3.873938e+01, dt=1.366951e-03, max(Re)=429251.700504
# 2024-04-06 11:55:41,192 __main__ 0/1 INFO :: Iteration=3551, Time=3.875250e+01, dt=1.366980e-03, max(Re)=442030.228099
# 2024-04-06 11:55:41,333 __main__ 0/1 INFO :: Iteration=3561, Time=3.876617e+01, dt=1.366980e-03, max(Re)=414995.261005
# 2024-04-06 11:55:41,531 __main__ 0/1 INFO :: Iteration=3571, Time=3.878095e+01, dt=1.478775e-03, max(Re)=451849.054196
# 2024-04-06 11:55:41,714 __main__ 0/1 INFO :: Iteration=3581, Time=3.879514e+01, dt=1.359199e-03, max(Re)=400471.373009
# 2024-04-06 11:55:41,906 __main__ 0/1 INFO :: Iteration=3591, Time=3.880945e+01, dt=1.430394e-03, max(Re)=499794.159913
# 2024-04-06 11:55:42,113 __main__ 0/1 INFO :: Iteration=3601, Time=3.882056e+01, dt=1.111369e-03, max(Re)=434715.516383
# 2024-04-06 11:55:42,298 __main__ 0/1 INFO :: Iteration=3611, Time=3.883329e+01, dt=1.272890e-03, max(Re)=459788.485014
# 2024-04-06 11:55:42,550 __main__ 0/1 INFO :: Iteration=3621, Time=3.884466e+01, dt=1.092386e-03, max(Re)=445255.280149
# 2024-04-06 11:55:42,794 __main__ 0/1 INFO :: Iteration=3631, Time=3.885727e+01, dt=1.331740e-03, max(Re)=486483.140540
# 2024-04-06 11:55:42,937 __main__ 0/1 INFO :: Iteration=3641, Time=3.887059e+01, dt=1.331740e-03, max(Re)=508407.668758
# 2024-04-06 11:55:43,117 __main__ 0/1 INFO :: Iteration=3651, Time=3.888084e+01, dt=1.024946e-03, max(Re)=467261.433324
# 2024-04-06 11:55:43,309 __main__ 0/1 INFO :: Iteration=3661, Time=3.889187e+01, dt=1.102582e-03, max(Re)=620663.873680
# 2024-04-06 11:55:43,451 __main__ 0/1 INFO :: Iteration=3671, Time=3.890289e+01, dt=1.102582e-03, max(Re)=609709.594375
# 2024-04-06 11:55:43,649 __main__ 0/1 INFO :: Iteration=3681, Time=3.891170e+01, dt=8.804286e-04, max(Re)=728321.334428
# 2024-04-06 11:55:43,790 __main__ 0/1 INFO :: Iteration=3691, Time=3.892050e+01, dt=8.804286e-04, max(Re)=524790.015146
# 2024-04-06 11:55:44,042 __main__ 0/1 INFO :: Iteration=3701, Time=3.892972e+01, dt=8.478023e-04, max(Re)=626283.755377
# 2024-04-06 11:55:44,284 __main__ 0/1 INFO :: Iteration=3711, Time=3.893835e+01, dt=8.133335e-04, max(Re)=639941.818277
# 2024-04-06 11:55:44,472 __main__ 0/1 INFO :: Iteration=3721, Time=3.894700e+01, dt=9.168953e-04, max(Re)=634702.870928
# 2024-04-06 11:55:44,668 __main__ 0/1 INFO :: Iteration=3731, Time=3.895561e+01, dt=8.615531e-04, max(Re)=558923.377396
# 2024-04-06 11:55:44,857 __main__ 0/1 INFO :: Iteration=3741, Time=3.896369e+01, dt=7.532451e-04, max(Re)=566307.582282
# 2024-04-06 11:55:45,118 __main__ 0/1 INFO :: Iteration=3751, Time=3.897270e+01, dt=9.253924e-04, max(Re)=581774.514806
# 2024-04-06 11:55:45,317 __main__ 0/1 INFO :: Iteration=3761, Time=3.898148e+01, dt=8.788209e-04, max(Re)=594568.461243
# 2024-04-06 11:55:45,562 __main__ 0/1 INFO :: Iteration=3771, Time=3.899027e+01, dt=8.113146e-04, max(Re)=726664.776915
# 2024-04-06 11:55:45,760 __main__ 0/1 INFO :: Iteration=3781, Time=3.899800e+01, dt=7.342025e-04, max(Re)=778182.830153
# 2024-04-06 11:55:45,952 __main__ 0/1 INFO :: Iteration=3791, Time=3.900572e+01, dt=8.114407e-04, max(Re)=682447.389428
# 2024-04-06 11:55:46,152 __main__ 0/1 INFO :: Iteration=3801, Time=3.901288e+01, dt=7.160096e-04, max(Re)=787162.686760
# 2024-04-06 11:55:46,420 __main__ 0/1 INFO :: Iteration=3811, Time=3.901925e+01, dt=6.789950e-04, max(Re)=937723.961544
# 2024-04-06 11:55:46,670 __main__ 0/1 INFO :: Iteration=3821, Time=3.902617e+01, dt=5.874836e-04, max(Re)=1086841.721895
# 2024-04-06 11:55:46,898 __main__ 0/1 INFO :: Iteration=3831, Time=3.903299e+01, dt=6.826132e-04, max(Re)=1013563.788104
# 2024-04-06 11:55:47,097 __main__ 0/1 INFO :: Iteration=3841, Time=3.903942e+01, dt=6.027863e-04, max(Re)=824782.556390
# 2024-04-06 11:55:47,348 __main__ 0/1 INFO :: Iteration=3851, Time=3.904690e+01, dt=7.839005e-04, max(Re)=804280.315788
# 2024-04-06 11:55:47,546 __main__ 0/1 INFO :: Iteration=3861, Time=3.905306e+01, dt=6.162914e-04, max(Re)=855193.950341
# 2024-04-06 11:55:47,745 __main__ 0/1 INFO :: Iteration=3871, Time=3.905859e+01, dt=5.531458e-04, max(Re)=938342.460745
# 2024-04-06 11:55:47,934 __main__ 0/1 INFO :: Iteration=3881, Time=3.906351e+01, dt=4.296440e-04, max(Re)=1389086.657683
# 2024-04-06 11:55:48,075 __main__ 0/1 INFO :: Iteration=3891, Time=3.906780e+01, dt=4.296440e-04, max(Re)=1204214.247653
# 2024-04-06 11:55:48,326 __main__ 0/1 INFO :: Iteration=3901, Time=3.907337e+01, dt=5.728664e-04, max(Re)=1151117.601607
# 2024-04-06 11:55:48,530 __main__ 0/1 INFO :: Iteration=3911, Time=3.907831e+01, dt=4.932257e-04, max(Re)=1148132.121734
# 2024-04-06 11:55:48,678 __main__ 0/1 INFO :: Iteration=3921, Time=3.908324e+01, dt=4.932257e-04, max(Re)=1332577.311579
# ...
# 2024-04-06 11:57:00,680 __main__ 0/1 INFO :: Iteration=7281, Time=3.925105e+01, dt=2.032403e-08, max(Re)=33112819166.217777
# 2024-04-06 11:57:00,925 __main__ 0/1 INFO :: Iteration=7291, Time=3.925105e+01, dt=1.973681e-08, max(Re)=26368678865.918648
# 2024-04-06 11:57:01,122 __main__ 0/1 INFO :: Iteration=7301, Time=3.925105e+01, dt=2.303219e-08, max(Re)=25834453971.159973
# 2024-04-06 11:57:01,317 __main__ 0/1 INFO :: Iteration=7311, Time=3.925105e+01, dt=2.080214e-08, max(Re)=30777038414.996471
# 2024-04-06 11:57:01,508 __main__ 0/1 INFO :: Iteration=7321, Time=3.925105e+01, dt=1.776099e-08, max(Re)=28617303666.927174
# 2024-04-06 11:57:01,704 __main__ 0/1 INFO :: Iteration=7331, Time=3.925105e+01, dt=1.907609e-08, max(Re)=28087372632.959404
# 2024-04-06 11:57:01,949 __main__ 0/1 INFO :: Iteration=7341, Time=3.925105e+01, dt=1.786081e-08, max(Re)=30644055946.041016
# 2024-04-06 11:57:02,143 __main__ 0/1 INFO :: Iteration=7351, Time=3.925105e+01, dt=2.075009e-08, max(Re)=35884935972.976120
# 2024-04-06 11:57:02,392 __main__ 0/1 INFO :: Iteration=7361, Time=3.925105e+01, dt=1.866199e-08, max(Re)=27347257822.408234
# 2024-04-06 11:57:02,535 __main__ 0/1 INFO :: Iteration=7371, Time=3.925105e+01, dt=1.866199e-08, max(Re)=29067666015.527184
# 2024-04-06 11:57:02,734 __main__ 0/1 INFO :: Iteration=7381, Time=3.925105e+01, dt=2.041348e-08, max(Re)=32802204684.233772
# 2024-04-06 11:57:02,930 __main__ 0/1 INFO :: Iteration=7391, Time=3.925105e+01, dt=1.757794e-08, max(Re)=38507211046.270279
# 2024-04-06 11:57:03,182 __main__ 0/1 INFO :: Iteration=7401, Time=3.925105e+01, dt=1.769132e-08, max(Re)=28886119480.014420
# 2024-04-06 11:57:03,370 __main__ 0/1 INFO :: Iteration=7411, Time=3.925105e+01, dt=1.513861e-08, max(Re)=35686253220.636528
# 2024-04-06 11:57:03,612 __main__ 0/1 INFO :: Iteration=7421, Time=3.925105e+01, dt=1.815156e-08, max(Re)=29445792550.398075
# 2024-04-06 11:57:03,810 __main__ 0/1 INFO :: Iteration=7431, Time=3.925105e+01, dt=1.564890e-08, max(Re)=35677282174.850815
# 2024-04-06 11:57:04,006 __main__ 0/1 INFO :: Iteration=7441, Time=3.925105e+01, dt=1.796963e-08, max(Re)=35398592472.695984
# 2024-04-06 11:57:04,147 __main__ 0/1 INFO :: Iteration=7451, Time=3.925105e+01, dt=1.796963e-08, max(Re)=35602787595.862839
# 2024-04-06 11:57:04,340 __main__ 0/1 INFO :: Iteration=7461, Time=3.925105e+01, dt=1.481759e-08, max(Re)=45678685881.515480
# 2024-04-06 11:57:04,534 __main__ 0/1 INFO :: Iteration=7471, Time=3.925105e+01, dt=1.595718e-08, max(Re)=37460572026.915138
# 2024-04-06 11:57:04,784 __main__ 0/1 INFO :: Iteration=7481, Time=3.925105e+01, dt=1.861242e-08, max(Re)=36355359111.903763
# 2024-04-06 11:57:05,032 __main__ 0/1 INFO :: Iteration=7491, Time=3.925105e+01, dt=1.442506e-08, max(Re)=44659055820.413147
# 2024-04-06 11:57:05,275 __main__ 0/1 INFO :: Iteration=7501, Time=3.925105e+01, dt=1.164653e-08, max(Re)=39494819809.407112
# 2024-04-06 11:57:05,546 __main__ 0/1 INFO :: Iteration=7511, Time=3.925105e+01, dt=1.183083e-08, max(Re)=47592487094.168571
# 2024-04-06 11:57:05,735 __main__ 0/1 INFO :: Iteration=7521, Time=3.925105e+01, dt=1.388337e-08, max(Re)=47410525413.872559
# 2024-04-06 11:57:05,925 __main__ 0/1 INFO :: Iteration=7531, Time=3.925105e+01, dt=1.295849e-08, max(Re)=40855897649.298492
# 2024-04-06 11:57:06,119 __main__ 0/1 INFO :: Iteration=7541, Time=3.925105e+01, dt=8.830011e-09, max(Re)=76480329490.209290
# 2024-04-06 11:57:06,311 __main__ 0/1 INFO :: Iteration=7551, Time=3.925105e+01, dt=9.655682e-09, max(Re)=54500262957.322746
# 2024-04-06 11:57:06,510 __main__ 0/1 INFO :: Iteration=7561, Time=3.925105e+01, dt=1.049761e-08, max(Re)=49707483842.945007
# 2024-04-06 11:57:06,705 __main__ 0/1 INFO :: Iteration=7571, Time=3.925105e+01, dt=8.883707e-09, max(Re)=56154750097.182983
# 2024-04-06 11:57:06,900 __main__ 0/1 INFO :: Iteration=7581, Time=3.925105e+01, dt=1.058519e-08, max(Re)=57109262982.360985
# 2024-04-06 11:57:07,095 __main__ 0/1 INFO :: Iteration=7591, Time=3.925105e+01, dt=1.118760e-08, max(Re)=60602568801.133575
# 2024-04-06 11:57:07,344 __main__ 0/1 INFO :: Iteration=7601, Time=3.925105e+01, dt=9.397852e-09, max(Re)=51261006147.653580
# 2024-04-06 11:57:07,540 __main__ 0/1 INFO :: Iteration=7611, Time=3.925105e+01, dt=9.930241e-09, max(Re)=62957059656.056770
# 2024-04-06 11:57:07,737 __main__ 0/1 INFO :: Iteration=7621, Time=3.925105e+01, dt=1.115469e-08, max(Re)=64220161237.941345
# 2024-04-06 11:57:07,979 __main__ 0/1 INFO :: Iteration=7631, Time=3.925105e+01, dt=8.855094e-09, max(Re)=73740160117.175629
# 2024-04-06 11:57:08,221 __main__ 0/1 INFO :: Iteration=7641, Time=3.925105e+01, dt=7.496109e-09, max(Re)=66820462357.225761
# 2024-04-06 11:57:08,414 __main__ 0/1 INFO :: Iteration=7651, Time=3.925105e+01, dt=8.252261e-09, max(Re)=73785435008.547729
# 2024-04-06 11:57:08,660 __main__ 0/1 INFO :: Iteration=7661, Time=3.925105e+01, dt=9.955957e-09, max(Re)=69887206721.153564
# 2024-04-06 11:57:08,901 __main__ 0/1 INFO :: Iteration=7671, Time=3.925105e+01, dt=8.562703e-09, max(Re)=75574669383.056076
# 2024-04-06 11:57:09,088 __main__ 0/1 INFO :: Iteration=7681, Time=3.925105e+01, dt=9.287824e-09, max(Re)=76516613265.259201
# 2024-04-06 11:57:09,334 __main__ 0/1 INFO :: Iteration=7691, Time=3.925105e+01, dt=7.961924e-09, max(Re)=72413632605.561966
# 2024-04-06 11:57:09,587 __main__ 0/1 INFO :: Iteration=7701, Time=3.925105e+01, dt=4.850967e-09, max(Re)=120484607488.195404
# 2024-04-06 11:57:09,785 __main__ 0/1 INFO :: Iteration=7711, Time=3.925105e+01, dt=5.437992e-09, max(Re)=78210112048.863266
# 2024-04-06 11:57:09,978 __main__ 0/1 INFO :: Iteration=7721, Time=3.925105e+01, dt=7.186327e-09, max(Re)=75757577758.101944
# 2024-04-06 11:57:10,166 __main__ 0/1 INFO :: Iteration=7731, Time=3.925105e+01, dt=8.015268e-09, max(Re)=77399992874.367813
# 2024-04-06 11:57:10,359 __main__ 0/1 INFO :: Iteration=7741, Time=3.925105e+01, dt=6.115228e-09, max(Re)=109646061179.219788
# 2024-04-06 11:57:10,556 __main__ 0/1 INFO :: Iteration=7751, Time=3.925105e+01, dt=5.269298e-09, max(Re)=92214833834.467896
# 2024-04-06 11:57:10,751 __main__ 0/1 INFO :: Iteration=7761, Time=3.925105e+01, dt=5.580729e-09, max(Re)=105801159726.487091
# 2024-04-06 11:57:10,996 __main__ 0/1 INFO :: Iteration=7771, Time=3.925105e+01, dt=5.545527e-09, max(Re)=88829439183.854675
# 2024-04-06 11:57:11,239 __main__ 0/1 INFO :: Iteration=7781, Time=3.925105e+01, dt=6.010678e-09, max(Re)=94015692496.373306
# 2024-04-06 11:57:11,379 __main__ 0/1 INFO :: Iteration=7791, Time=3.925105e+01, dt=6.010678e-09, max(Re)=98523787003.893311
# 2024-04-06 11:57:11,576 __main__ 0/1 INFO :: Iteration=7801, Time=3.925105e+01, dt=5.186663e-09, max(Re)=100600040572.938416
# 2024-04-06 11:57:11,716 __main__ 0/1 INFO :: Iteration=7811, Time=3.925105e+01, dt=5.186663e-09, max(Re)=112719511676.393204
# 2024-04-06 11:57:11,959 __main__ 0/1 INFO :: Iteration=7821, Time=3.925105e+01, dt=4.910315e-09, max(Re)=114505920899.198090
# 2024-04-06 11:57:12,146 __main__ 0/1 INFO :: Iteration=7831, Time=3.925105e+01, dt=4.146911e-09, max(Re)=138708541957.975800
# 2024-04-06 11:57:12,419 __main__ 0/1 INFO :: Iteration=7841, Time=3.925105e+01, dt=4.286617e-09, max(Re)=125462175378.870621
# 2024-04-06 11:57:12,609 __main__ 0/1 INFO :: Iteration=7851, Time=3.925105e+01, dt=4.503696e-09, max(Re)=135289639779.643356
# 2024-04-06 11:57:12,800 __main__ 0/1 INFO :: Iteration=7861, Time=3.925105e+01, dt=3.965475e-09, max(Re)=121766922975.270645
# 2024-04-06 11:57:13,038 __main__ 0/1 INFO :: Iteration=7871, Time=3.925105e+01, dt=3.915665e-09, max(Re)=137862142220.540741
# 2024-04-06 11:57:13,278 __main__ 0/1 INFO :: Iteration=7881, Time=3.925105e+01, dt=3.902079e-09, max(Re)=133706679020.740372
# 2024-04-06 11:57:13,522 __main__ 0/1 INFO :: Iteration=7891, Time=3.925105e+01, dt=3.766418e-09, max(Re)=134343547454.137680
# 2024-04-06 11:57:13,721 __main__ 0/1 INFO :: Iteration=7901, Time=3.925105e+01, dt=3.984249e-09, max(Re)=176671232117.981049
# 2024-04-06 11:57:13,983 __main__ 0/1 INFO :: Iteration=7911, Time=3.925105e+01, dt=2.847491e-09, max(Re)=164446953813.607483
# 2024-04-06 11:57:14,233 __main__ 0/1 INFO :: Iteration=7921, Time=3.925105e+01, dt=2.951145e-09, max(Re)=175947490306.464600
# 2024-04-06 11:57:14,483 __main__ 0/1 INFO :: Iteration=7931, Time=3.925105e+01, dt=3.177774e-09, max(Re)=176755020363.897156
# 2024-04-06 11:57:14,681 __main__ 0/1 INFO :: Iteration=7941, Time=3.925105e+01, dt=2.879197e-09, max(Re)=176177103066.565063
# 2024-04-06 11:57:14,876 __main__ 0/1 INFO :: Iteration=7951, Time=3.925105e+01, dt=3.327816e-09, max(Re)=207280523308.486877
# 2024-04-06 11:57:15,128 __main__ 0/1 INFO :: Iteration=7961, Time=3.925105e+01, dt=2.308982e-09, max(Re)=194189501477.738464
# 2024-04-06 11:57:15,376 __main__ 0/1 INFO :: Iteration=7971, Time=3.925105e+01, dt=1.751637e-09, max(Re)=207207257424.362671
# 2024-04-06 11:57:15,629 __main__ 0/1 INFO :: Iteration=7981, Time=3.925105e+01, dt=2.585036e-09, max(Re)=214180258126.122345
# 2024-04-06 11:57:15,876 __main__ 0/1 INFO :: Iteration=7991, Time=3.925105e+01, dt=2.396989e-09, max(Re)=266550707076.546204
# 2024-04-06 11:57:16,074 __main__ 0/1 INFO :: Iteration=8001, Time=3.925105e+01, dt=2.131687e-09, max(Re)=218574783932.062958
# 2024-04-06 11:57:16,268 __main__ 0/1 INFO :: Iteration=8011, Time=3.925106e+01, dt=1.688007e-09, max(Re)=263002468633.782532
# 2024-04-06 11:57:16,464 __main__ 0/1 INFO :: Iteration=8021, Time=3.925106e+01, dt=2.017277e-09, max(Re)=311870369876.689270
# 2024-04-06 11:57:16,711 __main__ 0/1 INFO :: Iteration=8031, Time=3.925106e+01, dt=2.094229e-09, max(Re)=251897900469.200928
# 2024-04-06 11:57:16,907 __main__ 0/1 INFO :: Iteration=8041, Time=3.925106e+01, dt=2.477593e-09, max(Re)=225854982970.609863
# 2024-04-06 11:57:17,158 __main__ 0/1 INFO :: Iteration=8051, Time=3.925106e+01, dt=2.388255e-09, max(Re)=256276868676.697754
# 2024-04-06 11:57:17,352 __main__ 0/1 INFO :: Iteration=8061, Time=3.925106e+01, dt=2.263422e-09, max(Re)=302085475751.611267
# 2024-04-06 11:57:17,553 __main__ 0/1 INFO :: Iteration=8071, Time=3.925106e+01, dt=1.802448e-09, max(Re)=322365261598.641052
# 2024-04-06 11:57:17,803 __main__ 0/1 INFO :: Iteration=8081, Time=3.925106e+01, dt=1.939529e-09, max(Re)=282791390729.566406
# 2024-04-06 11:57:17,942 __main__ 0/1 INFO :: Iteration=8091, Time=3.925106e+01, dt=1.939529e-09, max(Re)=284487267710.010925
# 2024-04-06 11:57:18,085 __main__ 0/1 INFO :: Iteration=8101, Time=3.925106e+01, dt=1.939529e-09, max(Re)=332533785929.266968
# 2024-04-06 11:57:18,311 __main__ 0/1 INFO :: Iteration=8111, Time=3.925106e+01, dt=1.528967e-09, max(Re)=309272284666.384521
# 2024-04-06 11:57:18,507 __main__ 0/1 INFO :: Iteration=8121, Time=3.925106e+01, dt=1.350195e-09, max(Re)=339443888064.439087
# 2024-04-06 11:57:18,646 __main__ 0/1 INFO :: Iteration=8131, Time=3.925106e+01, dt=1.350195e-09, max(Re)=458023173582.272583
# 2024-04-06 11:57:18,841 __main__ 0/1 INFO :: Iteration=8141, Time=3.925106e+01, dt=1.164232e-09, max(Re)=465734217976.680298
# 2024-04-06 11:57:18,882 __main__ 0/1 ERROR :: Exception raised, triggering end of main loop.
# 2024-04-06 11:57:18,883 solvers 0/1 INFO :: Final iteration: 8141
# 2024-04-06 11:57:18,883 solvers 0/1 INFO :: Final sim time: 39.25105525507245
# 2024-04-06 11:57:18,884 solvers 0/1 INFO :: Setup time (init - iter 0): 2.356 sec
# 2024-04-06 11:57:18,884 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.2951 sec
# 2024-04-06 11:57:18,884 solvers 0/1 INFO :: Run time (iter 10-end): 171.9 sec
# 2024-04-06 11:57:18,885 solvers 0/1 INFO :: CPU time (iter 10-end): 0.04775 cpu-hr
# 2024-04-06 11:57:18,885 solvers 0/1 INFO :: Speed: 1.61e+06 mode-stages/cpu-sec
# /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/transforms.py:162: SyntaxWarning: invalid escape sequence '\s'
#   """
# /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/transforms.py:334: SyntaxWarning: invalid escape sequence '\s'
#   """
# /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/transforms.py:633: SyntaxWarning: invalid escape sequence '\s'
#   """
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 87
#      85 while solver.proceed:
#      86     timestep = CFL.compute_timestep()
# ---> 87     solver.step(timestep)
#      88     if (solver.iteration-1) % 10 == 0:
#      89         max_Re = flow.max('Re')
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/solvers.py:686, in InitialValueSolver.step(self, dt)
#     684         self.run_profiler.enable()
#     685 # Advance using timestepper
# --> 686 self.timestepper.step(dt, wall_time)
#     687 # Update iteration
#     688 self.iteration += 1
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/timesteppers.py:598, in RungeKuttaIMEX.step(self, dt, wall_time)
#     596     evaluator.evaluate_scheduled(iteration=iteration, wall_time=wall_time, sim_time=solver.sim_time, timestep=dt)
#     597 else:
# --> 598     evaluator.evaluate_group('F')
#     599 Fi = F[i-1]
#     600 for sp in subproblems:
#     601     # F fields should be in coeff space from evaluator
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/evaluator.py:87, in Evaluator.evaluate_group(self, group, **kw)
#      85 """Evaluate all handlers in a group."""
#      86 handlers = self.groups[group]
# ---> 87 self.evaluate_handlers(handlers, **kw)
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/evaluator.py:144, in Evaluator.evaluate_handlers(self, handlers, id, **kw)
#     130 # # Transform all outputs to coefficient layout to dealias
#     131 ## D3 note: need to worry about this for redundent tasks?
#     132 # outputs = OrderedSet([t['out'] for h in handlers for t in h.tasks])
#    (...)
#     141 #         else:
#     142 #             outputs.add(task['out'])
#     143 outputs = OrderedSet([t['out'] for h in handlers for t in h.tasks if not isinstance(t['out'], LockedField)])
# --> 144 self.require_coeff_space(outputs)
#     146 # Process
#     147 for handler in handlers:
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/evaluator.py:165, in Evaluator.require_coeff_space(self, fields)
#     163 for index in range(max(layouts.keys()), coeff_layout.index, -1):
#     164     current_fields.extend(layouts[index])
# --> 165     self.dist.paths[index-1].decrement(current_fields)
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/distributor.py:616, in Transform.decrement(self, fields)
#     614 else:
#     615     for field in fields:
# --> 616         self.decrement_single(field)
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/distributor.py:643, in Transform.decrement_single(self, field)
#     641 # Transform non-constant bases with local data
#     642 if (basis is not None) and prod(gdata.shape):
# --> 643     basis.forward_transform(field, axis, gdata, cdata)
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/basis.py:926, in FourierBase.forward_transform(self, field, axis, gdata, cdata)
#     924 def forward_transform(self, field, axis, gdata, cdata):
#     925     # Transform
# --> 926     super().forward_transform(field, axis, gdata, cdata)
#     927     # Permute coefficients
#     928     if self.forward_coeff_permutation is not None:
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/basis.py:421, in IntervalBasis.forward_transform(self, field, axis, gdata, cdata)
#     419 grid_size = gdata.shape[data_axis]
#     420 plan = self.transform_plan(field.dist, grid_size)
# --> 421 plan.forward(gdata, cdata, data_axis)
#
# File /opt/anaconda3/envs/dedalus3/lib/python3.12/site-packages/dedalus/core/transforms.py:555, in FFTWRealFFT.forward(self, gdata, cdata, axis)
#     553 plan, temp = self._build_fftw_plan(gdata.shape, axis)
#     554 # Execute FFTW plan
# --> 555 plan.forward(gdata, temp)
#     556 # Unpack from complex form and rescale
#     557 self.unpack_rescale(temp, cdata, axis, rescale=1/self.N)
#
# KeyboardInterrupt:

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from dedalus.extras import plot_tools
import pathlib
from dedalus.tools import logging
from dedalus.tools import post
from dedalus.tools.parallel import Sync

# Function to plot snapshots
def plot_snapshots(filename, output_path):
    """Save plot of specified tasks for given range of analysis writes."""
    
    # Plot settings
    tasks = ['buoyancy', 'vorticity']
    scale = 1.5
    dpi = 200
    title_func = lambda sim_time: 't = {:.3f}'.format(sim_time)
    savename_func = lambda write: 'write_{:06}.png'.format(write)

    # Layout
    nrows, ncols = 2, 1
    image = plot_tools.Box(4, 1)
    pad = plot_tools.Frame(0.3, 0, 0, 0)
    margin = plot_tools.Frame(0.2, 0.1, 0, 0)

    # Create multifigure
    mfig = plot_tools.MultiFigure(nrows, ncols, image, pad, margin, scale)
    fig = mfig.figure

    # Ensure output directory exists
    pathlib.Path(output_path).mkdir(parents=True, exist_ok=True)

    # Plot writes
    with h5py.File(filename, mode='r') as file:
        frame_count = file['tasks'][tasks[0]].shape[0]
        for index in range(frame_count):
            for n, task in enumerate(tasks):
                # Build subfigure axes
                i, j = divmod(n, ncols)
                axes = mfig.add_axes(i, j, [0, 0, 1, 1])
                # Call 3D plotting helper, slicing in time
                dset = file['tasks'][task]
                plot_tools.plot_bot_3d(dset, 0, index, axes=axes, title=task, even_scale=True, visible_axes=False)
            # Add time title
            title = title_func(file['scales/sim_time'][index])
            title_height = 1 - 0.5 * mfig.margin.top / mfig.fig.y
            fig.suptitle(title, x=0.44, y=title_height, ha='left')
            # Save figure
            savename = savename_func(file['scales/write_number'][index])
            savepath = pathlib.Path(output_path).joinpath(savename)
            fig.savefig(str(savepath), dpi=dpi)
            fig.clear()
    plt.close(fig)

# %%
# Directory containing the HDF5 files
snapshot_dir = pathlib.Path('snapshots')

# Get a sorted list of HDF5 files
snapshot_files = sorted(snapshot_dir.glob('snapshots_s*.h5'))
print(snapshot_files)

# Output directory for the plots
output_directory = './frames'

# Loop over each file and process it
for file_path in snapshot_files:
    print(f"Processing {file_path.name}...")
    plot_snapshots(str(file_path), output_directory)
# Out:
# [PosixPath('snapshots/snapshots_s1.h5'), PosixPath('snapshots/snapshots_s2.h5'), PosixPath('snapshots/snapshots_s3.h5'), PosixPath('snapshots/snapshots_s4.h5')]
# Processing snapshots_s1.h5...
# Processing snapshots_s2.h5...
# Processing snapshots_s3.h5...
# Processing snapshots_s4.h5...

# %%
import cv2
import os
import numpy as np

# Directory containing the frames
frames_dir = 'frames'
# Output video file
output_video = 'output_video.avi'

# Assuming all images are the same size, get dimensions from the first image
sample_img = cv2.imread(os.path.join(frames_dir, os.listdir(frames_dir)[0]))
height, width, layers = sample_img.shape

# Video properties
frame_rate = 20  # Frames per second
frame_size = (width, height)

# Retrieve file names and sort them
frame_files = [f for f in os.listdir(frames_dir) if os.path.isfile(os.path.join(frames_dir, f))]
frame_files.sort(key=lambda x: int(''.join(filter(str.isdigit, x))))

# Initialize video writer
fourcc = cv2.VideoWriter_fourcc(*'XVID')
video_writer = cv2.VideoWriter(output_video, fourcc, frame_rate, frame_size)

# Add images to video
for frame in frame_files:
    img_path = os.path.join(frames_dir, frame)
    img = cv2.imread(img_path)
    video_writer.write(img)

# Release the video writer
video_writer.release()

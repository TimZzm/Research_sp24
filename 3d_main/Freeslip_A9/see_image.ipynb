# %%
from IPython.display import Image
from IPython.display import display
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
i0 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 10 )}.png')
i1 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 620 )}.png')
i2 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 700 )}.png') 
i3 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 800 )}.png') 
i4 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 900 )}.png') 
i5 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1000 )}.png') 
i6 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1100 )}.png') 
i7 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1200 )}.png') 
i8 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1300 )}.png') 
i9 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1400 )}.png') 
i10 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1500 )}.png') 
i11 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1600 )}.png')
i12 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1700 )}.png') 
i13 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1800 )}.png') 
i14 = Image(filename=f'liquid_water/liquidwater_{"%04d" % ( 1900 )}.png')
display(i0, i1, i2, i3, i4, i5, i6, i7, i8, i9, i10, i11, i12, i13, i14)

# %%
import cv2
import os
import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       2 import os
#       3 import glob
#
# ModuleNotFoundError: No module named 'cv2'
